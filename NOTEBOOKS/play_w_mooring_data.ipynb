# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from s3fs import S3FileSystem, S3Map

import cmocean as cm
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# %matplotlib notebook

# %%
plt.rcParams['font.size']=14
plt.rcParams['axes.labelsize']='large'
plt.rcParams['pcolor.shading']='auto'

# %%
# Mode amplitudes
# N280
ds = xr.open_dataset('../DATA/FV03/stacked_moorings_tp/[BB23]_[BB23_REC]_[N280]_[multi(27)_nominal_instrument_height_asb]_[multi(3)_instrument_model]_[multi(27)_instrument_serial_number]_[no_outfile_append].nc')
# S245
ds = xr.open_dataset('../DATA/FV03/stacked_moorings_tp/[BB23]_[BB23_REC]_[S245]_[multi(35)_nominal_instrument_height_asb]_[multi(2)_instrument_model]_[multi(35)_instrument_serial_number]_[no_outfile_append].nc')
# W310
# ds = xr.open_dataset('../DATA/FV03/stacked_moorings_tp/[BB23]_[BB23_REC]_[W310]_[multi(26)_nominal_instrument_height_asb]_[multi(4)_instrument_model]_[multi(26)_instrument_serial_number]_[no_outfile_append].nc')

ds
# Out:
# <xarray.Dataset>
# Dimensions:           (z_nom: 35, time: 61920, timeslow: 345, modes: 4, z_interp: 101)
# Coordinates:
#   * z_nom             (z_nom) float64 -244.4 -239.4 -231.8 ... -19.12 -12.62
#   * time              (time) datetime64[ns] 2023-04-19T00:00:00.028800 ... 20...
#     lat_nom           float64 ...
#     lon_nom           float64 ...
#   * timeslow          (timeslow) datetime64[ns] 2023-04-19 ... 2023-06-01
#   * modes             (modes) int32 0 1 2 3
#   * z_interp          (z_interp) float64 0.0 -2.8 -5.6 ... -274.4 -277.2 -280.0
# Data variables: (12/13)
#     Temperature       (z_nom, time) float64 ...
#     Pressure          (z_nom, time) float64 ...
#     source            (z_nom) object ...
#     Salinity          (z_nom, time) float64 ...
#     Depth             (z_nom) float64 ...
#     Density           (z_nom, time) float64 ...
#     ...                ...
#     A_n               (time, modes) float64 ...
# ...

# %%
plt.figure()
ds['A_n'][:,0].plot(lw=0.2)

# ds['A_n'][:,1].plot(lw=0.2)
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
# W310
ds = xr.open_dataset('../DATA/FV02/stacked_moorings_tp/[BB23]_[BB23_REC]_[W310]_[multi(26)_nominal_instrument_height_asb]_[multi(4)_instrument_model]_[multi(26)_instrument_serial_number]_[no_outfile_append].nc')

# S245
ds = xr.open_dataset('../DATA/FV02/stacked_moorings_tp/[BB23]_[BB23_REC]_[S245]_[multi(36)_nominal_instrument_height_asb]_[multi(3)_instrument_model]_[multi(36)_instrument_serial_number]_[no_outfile_append].nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (z_nom: 36, time: 61920)
# Coordinates:
#   * z_nom        (z_nom) float64 -244.4 -239.4 -234.8 ... -22.87 -19.12 -12.62
#   * time         (time) datetime64[ns] 2023-04-19T00:00:00.028800 ... 2023-05...
#     lat_nom      float64 ...
#     lon_nom      float64 ...
# Data variables:
#     Temperature  (z_nom, time) float64 ...
#     Pressure     (z_nom, time) float64 ...
#     source       (z_nom) object ...
# Attributes: (12/35)
#     title:                           Mooring made by stacking multipe files
#     institution:                     The University of Western Australia
#     institution_division:            Ocean Dynamics
#     source:                          D:\BB23(All)\data\moored_instrument_data...
#     project:                         BB23
#     history:
#     ...                              ...
#     nominal_instrument_height_asb:   0.6;5.625;13.177;19.177;22.177;25.177;28...
#     nominal_instrument_orientation:
# ...

# %%
plt.figure()
ds['Temperature'].plot(cmap='cmo.thermal')
ds['Temperature'].plot.contour(levels=np.arange(12,30,1), colors='k', linewidths=0.2)
# Out:
# <img src="data:image/png;base64,..." width="942.5166666666667">

# %%
ds['Temperature'].plot.contour(leve)

# %%
ds['Temperature'].plot.contour
